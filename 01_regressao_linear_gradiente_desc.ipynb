# %%
import numpy as np

# %%
data = np.loadtxt(completar...)

X = data[,] # obter segunda coluna
y = data[,]  # obter última coluna

# %%
def regressao_linear(X, y, alpha, n_epocas):
    w0 = 0
    w1 = 0

    for i in range(n_epocas):
        # y_ = y chapéu
        y_ =    # multiplicacao vetor X x w1 + w0
        e =     # y-y_
        soma_ex_ = # somatório de ei x xi
        soma_e =  # somatório de e
        print(soma_e)
        w0 =    # atulizar w0
        w1 =    # atualizar w1

    return w0, w1

def regressao_linear_v2(X, y, alpha, n_epocas):
    w0 = 0
    w1 = 0

    for i in range(n_epocas):
        y_ = []
        e = []
        for j in range(len(X)):
            y_i = # calcular a equação da reta para essa amostra
            y_.append(y_i)
            e_i = # calcular o resíduo para essa amostra
            e_i.append(e_i)


        soma_ex_ = # somatório de ei x xi
        soma_e =  # somatório de e
        w0 =    # atulizar w0
        w1 =    # atualizar w1

# %%
w0, w1 = regressao_linear(X, y, 0.01, 1000)
print(w0, w1)
