# %% [markdown]
# # **EXPERIMENTO 01 - Regressão Linear Univariada - Método Analítico**

# %%
# Importação do conjunto de dados "Boston House Price Dataset.csv".

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

data = np.loadtxt("boston_housing.csv", delimiter=",", skiprows=1)

V = data[:,[1,3]]

# %%
# Implantação da função "standardize(V)" que recebe um vetor V e retorna o vetor V padronizado.

# Padronização da variável LSTAT como atributo preditor e da variável MEDV como atributo alvo. Obtendo o vetor as observações da coluna LSTAT e o vetor com as observações da coluna MEDV.

def standardize (V):

    data_padronizado = np.zeros(V.shape)

    media0 = np.mean(V[:,0])
    desv0 = np.std(V[:,0])
    data_padronizado[:,0] = (V[:,0] - media0) / desv0

    media1 = np.mean(V[:,1])
    desv1 = np.std(V[:,1])
    data_padronizado[:,1] = (V[:,1] - media1) / desv1

    return (data_padronizado)

# %%
# Valores padronizados.

data_padronizado = standardize(V)

X_true = data_padronizado[:,0]
y_true = data_padronizado[:,1]

df_pandas = pd.DataFrame (data_padronizado, columns = ['X','Y'])

X_p = df_pandas['X']
y_p = df_pandas['Y']

# %%
# Treinamento do método de regressão linear univariada usando o método "analítico".

def regressao_linear(X, y):
    X_ = np.mean(X)
    y_ = np.mean(y)

    b1 = (np.sum((X-X_)*(y-y_)))/np.sum((X-X_)**2)
    b0 = y_- (b1*X_)

    return (b0, b1)

# %%
# Coeficientes finais

b0, b1 = regressao_linear(X_true, y_true)
print ("b0:", np.round(b0, 4), f"\n", "b1:", np.round(b1, 4))
# Out:
# b0: -0.0
#  b1: -0.7607

# %%
# Resumo da análise da regressão, utilizando a biblioteca statsmodels (com o método Ordinary Least Squares).

modelo = smf.ols ('Y ~ X', data = df_pandas)
modelo = modelo.fit()
modelo.summary()

print (modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.578
# Method:                 Least Squares   F-statistic:                     668.7
# Date:                Fri, 24 Oct 2025   Prob (F-statistic):           1.93e-93
# Time:                        12:40:09   Log-Likelihood:                -482.56
# No. Observations:                 489   AIC:                             969.1
# Df Residuals:                     487   BIC:                             977.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.361e-17      0.029   4.63e-16      1.000      -0.058       0.058
# X             -0.7607      0.029    -25.860      0.000      -0.818      -0.703
# ==============================================================================
# Omnibus:                      105.652   Durbin-Watson:                   1.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              198.227
# Skew:                           1.217   Prob(JB):                     9.03e-44
# Kurtosis:                       4.950   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Predições, Predições convertidas de volta à unidade original (Revertidas à escala original), MSE e R² obtidos com o modelo final.

def predict_univariate(X, b0, b1):
    y_predict = b0 + (b1*X)

    return y_predict

def predict_univariate_esc_original(y_predict):

    y_predict_orig = y_predict * np.std(V[:,1]) + np.mean(V[:,1])

    return y_predict_orig

def MSE (y_true, y_predict):
    mse = np.mean ((y_true - y_predict)**2)

    return mse

def R2 (y_true, y_predict):
    r2 = 1 - np.sum((y_true-y_predict)**2) / np.sum((y_true-(np.mean(y_true)))**2)

    return r2

# %%
# Predições.

y_predict = predict_univariate(X_true, b0, b1)
print ("Predições:", f"\n", np.round(y_predict, 2))
# Out:
# Predições:
#  [ 0.86  0.41  0.96  1.08  0.82  0.83  0.05 -0.67 -1.83 -0.45 -0.81 -0.04
#  -0.3   0.5   0.29  0.48  0.68 -0.19  0.13  0.18 -0.87 -0.1  -0.62 -0.75
#  -0.36 -0.38 -0.2  -0.47  0.02  0.1  -1.04 -0.01 -1.59 -0.58 -0.8   0.35
#   0.16  0.45  0.3   0.93  1.18  0.87  0.77  0.59  0.36  0.29 -0.13 -0.63
#  621271.46 567461.55 519867.3  628907.85 545795.51 561601.06 513829.22
#  555207.8  579182.52 484349.2  540290.2  498556.44 421482.17 628019.9
#  441727.48 453270.86 567106.36 546861.05 567283.96 621449.05 631216.53
#  576696.25 610260.85 556450.94 598007.11 617364.47 602624.46 630683.76
#  544729.96 537981.53 454514.   557338.89 549169.73 515249.94 625000.86
#  620916.28 600670.97 531765.86 499444.39 572789.26 552899.13 402835.17
#  595876.02 599960.6  576341.07 515427.53 530167.54 597829.52 561068.29
#  525550.19 569237.45 550412.86 603512.41 507080.78 459664.12 577939.38
#  476002.45 543842.01 519334.52 479909.44 358615.14 401059.26 500154.75
#  458065.81 556273.35 562133.83 547393.82 475647.27 575453.12 593922.53
#  574920.35 457000.26 507080.78 553787.08 522708.74 463393.52 545085.14
#  583267.1  564264.92 541888.52 510099.82 496602.94 533008.99 511165.36
#  519156.93 586641.32 530522.73 556628.53 602269.28 497135.71 459131.35
#  571190.95 577761.79 579537.7  577939.38 586641.32 545795.51 604222.78
#  541178.15 585220.59 371579.24 448475.92 480264.62 459131.35 545795.51
#  432137.6  503173.79 424146.03 557694.07 435511.82 447410.38  66656.38
#    9827.43 445456.88 271418.21 306936.31 263426.64 297346.42 378505.27
#  309777.75 265024.95 247976.27 140178.84 136982.21 181912.61 116026.54
#  140356.43 313862.34 380281.18 350978.75 228086.13 414733.73 393778.05
#  380103.59 340145.73 330378.25 140889.2  151899.81 208728.77 323274.63
#  323452.22 333042.11 197895.75 276035.56 269642.31 468721.24 215299.62
#  332864.52 504594.51 307291.49  73760.   327536.8   27408.89 168238.14
#  226132.64 211037.45 317946.92 280297.73 417397.59 405321.43 433735.91
#  270530.26 379393.22 250995.3  405499.02 426277.11 301963.77 256500.61
#  370868.88 334462.83 470497.14 396086.73 414733.73 270885.44 363587.67
#  214411.66  79975.67 277811.47 291485.93 337481.87 389515.88 349380.43
#  261650.73 258276.51 368205.02 392179.74 362166.95 341211.27 374420.69
#  369270.57 377439.73 386852.02 351866.7  362166.95 346538.98 383300.21
#  395909.14 423080.48 392534.92 423968.44 435689.41 501397.89 449363.87
#  433203.14 379570.81 305515.58 362166.95 422014.94 394843.6  455579.54
#  429118.56 477067.99 361989.36 256145.43 352399.47 241760.6  363942.85
#  451317.37 493406.31 546683.46 559647.56 499089.21 447232.79 496247.76
#  418107.95 480797.39 363410.08 258454.1  157049.94 363232.49 447055.2
#  470852.32 442793.03 371579.24 308712.21 433735.91 454691.59 415976.86
#  429651.33 512408.5  522886.33 583977.46 569059.86 544197.19]

# %%
# MSE

mse = MSE (y_true, y_predict)
print ("MSE:", f" {mse:.2f}")
# Out:
# MSE:  0.42

# %%
# R²

r2 = R2 (y_true, y_predict)
print ("R2:", f" {r2:.2f}")
# Out:
# R2:  0.58

# %%
# Visualização gráfica da regressão linear univariada pelo método analítico.

plt.scatter(X_true, y_true, label = "Dados reais Y(X)", s=30, alpha=0.5)
plt.plot(X_true, y_predict, color='red', label = "Regressão", linewidth=2)
plt.suptitle("Como a variação na condição socioeconômica da vizinhança\ninfluencia o valor médio das residências?", fontsize=12, fontweight='bold', y=1.05)
plt.title("Regressão Linear Univariada - Método Analítico", fontsize=10, fontweight='bold', pad =15)
plt.xlabel("X - Baixo Status Socioeconômico (%)", fontsize=10)
plt.ylabel("Y - Valor das Casas (US$)", fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
