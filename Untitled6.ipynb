# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
diab = datasets.load_diabetes()
df = diab.data([])
df.rename(columns={"target": "disease_progression"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2042078787.py in <cell line: 0>()
#       1 diab = datasets.load_diabetes()
# ----> 2 df = diab.data([])
#       3 df.rename(columns={"target": "disease_progression"}, inplace=True)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
print(df[["bmi", "disease_progression"]].describe().round(3))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1178864456.py in <cell line: 0>()
# ----> 1 print(df[["bmi", "disease_progression"]].describe().round(3))
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
sns.scatterplot(x="bmi", y="disease_progression", data=df)
plt.title("Dispersão: BMI vs Progressão da Doença")
plt.show()

# %%
X = df["bmi"]
y = df["disease_progression"]

# %%
def regressao_linear(X,y):
  y_ = np.mean(y)
  x_ = np.mean(X)
  b1 = np.sum((X-x_)*(y-y_))/np.sum((X-x_)**2)
  b0 = y_ - b1*x_
  return b0, b1

# %%
b0, b1 = regressao_linear(X,y)
print(b0, b1)

# %%
def predicao (X, b0, b1):
  y_pred = b0 + b1*X
  return y_pred

# %%
def RSS (y, y_pred):
  rss = np.sum((y-y_pred)**2)
  return rss

def TSS (y):
  tss = np.sum((y-(np.mean(y)))**2)
  return tss

# %%
y_pred = predicao(X, b0, b1)
print(y_pred)

rss = RSS(y, y_pred)
print("RSS:", rss)

tss = TSS(y)
print("TSS:", tss)

R2 = 1 - (rss/tss)
print("R2:", R2)

# %%
sns.scatterplot(x="bmi", y="disease_progression", data=df)
plt.plot(X, y_pred, color="red")
plt.title("Regressão Linear: BMI / Progressão da Doença")
plt.show()
