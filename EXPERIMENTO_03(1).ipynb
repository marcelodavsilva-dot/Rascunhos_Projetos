# %% [markdown]
# # **EXPERIMENTO - 03**

# %% [markdown]
# # **Treinamento do modelo com o método "REDES NEURAIS ARTIFICIAIS".**

# %%
# Importação de bibliotecas e APIs.

import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, recall_score, precision_score

# %%
# Importação do dataset "diabetes.csv".

df = np.loadtxt("diabetes.csv", delimiter=",", skiprows=1)

# %%
print (df.shape)
# Out:
# (768, 9)

# %%
# Criação da matriz X com as variáveis de entrada e o vetor y com a variável de saída.

X = df[:,0:8]
y = df[:,8]

# %%
# Separação do conjunto de treino e teste (70%/30%).

X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Padronização das variáveis.

padronizacao = StandardScaler().fit(X_treino)
X_treino_padronizado = padronizacao.transform(X_treino)
X_teste_padronizado = padronizacao.transform(X_teste)

# %%
# Treinamento do modelo com o modelo "REDES NEURAIS ARTIFICIAIS".

clf = MLPClassifier(hidden_layer_sizes=(100,10), max_iter = 500, random_state = 42)
clf.fit(X_treino_padronizado, y_treino)

clf.predict_proba(X_teste_padronizado[:10])
y_pred = clf.predict(X_teste_padronizado)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Reporte da acurácia.

print (f" Acurácia: {accuracy_score(y_teste, y_pred):.4f}")
# Out:
#  Acurácia: 0.7013

# %%
# Reporte do Recall.

print (f" Recall: {recall_score (y_teste, y_pred):.4f}")
# Out:
#  Recall: 0.5432

# %%
# Reporte da precision.

print (f" Precision: {precision_score(y_teste, y_pred):.4f}")
# Out:
#  Precision: 0.5789

# %%
cm = confusion_matrix(y_teste, y_pred)

# %%
# Exibição da Matriz de Confusão.

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Matriz de confusão", fontsize=20, y=1.03)
plt.show()

# %%
q_neuronios = (2, 10, 50, 200)

for i in q_neuronios:

  clf = MLPClassifier(hidden_layer_sizes=(i,10), max_iter = 500, random_state = 42)
  clf.fit(X_treino_padronizado, y_treino)

  clf.predict_proba(X_teste_padronizado[:10])
  y_pred = clf.predict(X_teste_padronizado)

  print (f"\n", "Quantidade de neurônios:", i, f"\n")

  print (f"Acurácia: {accuracy_score(y_teste, y_pred):.4f}" f"\n")

  print (f"Recall: {recall_score (y_teste, y_pred):.4f}", f"\n")

  print (f"Precision: {precision_score(y_teste, y_pred):.4f}", f"\n")

  cm = confusion_matrix(y_teste, y_pred)

  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot(cmap='Blues')
  plt.title("Matriz de confusão", fontsize=20, y=1.03)
  plt.show()
# Out:
#  Quantidade de neurônios: 2
#
# Acurácia: 0.7403
#
# Recall: 0.5556
#
# Precision: 0.6522
#  Quantidade de neurônios: 10
#
# Acurácia: 0.7273
#
# Recall: 0.5556
#
# Precision: 0.6250
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
#  Quantidade de neurônios: 50
#
# Acurácia: 0.7056
#
# Recall: 0.5802
#
# Precision: 0.5802
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
#  Quantidade de neurônios: 200
#
# Acurácia: 0.7532
#
# Recall: 0.6049
#
# Precision: 0.6622
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
